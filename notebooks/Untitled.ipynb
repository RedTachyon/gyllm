# %%
import gyllm

# %%
env = gyllm.make("simple/tic_tac_toe")

# %%
reqs = env.reset()

# %%
reqs
# Out:
# [{'actor': 'player_a',
#   'reward': 0.0,
#   'system_message': {'role': 'system',
#    'content': 'You are playing Tic-Tac-Toe on a 3x3 grid.\nWin by getting 3 in a row (horizontal/vertical/diagonal).\nYou are X.\nX goes first, O goes second.\n\nChoose an empty cell by responding with either:\n- an integer index 0..8 (row-major), or\n- a JSON object like {"index": 4} or {"row": 1, "col": 1}.\nInvalid actions lose the game.'},
#   'message': {'role': 'user',
#    'content': 'New game.\n\nBoard:\n  0 1 2\n0 . . .\n1 . . .\n2 . . .\n\nLegal actions: [0, 1, 2, 3, 4, 5, 6, 7, 8]\nYour turn.'},
#   'needs_action': True,
#   'info': {'legal_actions': [0, 1, 2, 3, 4, 5, 6, 7, 8]},
#   'episode_id': 1,
#   'episode_start': True,
#   'episode_end': False}]

# %%
reqs1 = env.step({"player_a": "0"})

# %%
reqs1
# Out:
# [{'actor': 'player_b',
#   'reward': 0.0,
#   'message': {'role': 'user',
#    'content': 'player_a played (0, 0). Move accepted.\n\nBoard:\n  0 1 2\n0 X . .\n1 . . .\n2 . . .\n\nLegal actions: [1, 2, 3, 4, 5, 6, 7, 8]\nYour turn.'},
#   'needs_action': True,
#   'info': {'legal_actions': [1, 2, 3, 4, 5, 6, 7, 8]},
#   'episode_id': 1,
#   'episode_start': False,
#   'episode_end': False}]
